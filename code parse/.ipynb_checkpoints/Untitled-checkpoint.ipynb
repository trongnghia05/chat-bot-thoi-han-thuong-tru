# %%
import xlrd
import json

# %%
list_xlsx=[]
workbook = xlrd.open_workbook("/root/PycharmProjects/chat-bot/Noi thuong tru/noi_tam_tru.xlsx")
sheet = workbook.sheet_by_index(0)
closs = []
for rowx in range(sheet.nrows):
    cols = sheet.row_values(rowx)
    closs.append(cols)

# %%
def test(arr):
    # 3456,456,346,356,56,46
    valueLastItems = int(arr[arr.__len__()-1])
    
    if valueLastItems == 10:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +  " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a +  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a +  "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
            
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
  
    
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
      
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
    #3456,346,356
    if valueLastItems == 11:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +  " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        
        a = a +  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
     
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
    #345678,3568,3578,4568,4578,35678,45678
    if valueLastItems == 12:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+ " " + arr[7] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " " + arr[5] + " " + arr[6]+ " " + arr[7] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+" " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]+ " " + arr[5] + " " + arr[6]+ " " + arr[7] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " " + arr[5] + " " + arr[6] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " * " + arr[6] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[7] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " " + arr[5] + " " + arr[7] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]+ " " + arr[5] + " " + arr[6] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " * " + arr[6] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[7] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]+ " " + arr[5] + " " + arr[7] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
    #3456,356,456
    if valueLastItems == 13:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]   + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+ "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]+ " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
      
    
     #34567,3457,3467,3567
    if valueLastItems == 14:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]   + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +" " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[7]   + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[7]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[7]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[7]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[7]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[7]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[7]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6] + " " + arr[7]   + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[6] + " " + arr[7]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6] + " " + arr[7]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6] + " * " + arr[7]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6] + " * " + arr[7]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6] + " * " + arr[7]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6] + " * " + arr[7]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7]   + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
     #3456,346,356
    if valueLastItems == 15:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
     
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
    #345,45
    if valueLastItems == 16:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
     
    #3456789,3789,4789,5789,6789
    if valueLastItems == 17:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" " + arr[9] +  "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" " + arr[9] + " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+ " " + arr[7] + " " + arr[8] +" " + arr[9] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7] + " " + arr[8] +" " + arr[9] + " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" * " + arr[9] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" * " + arr[9] + " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" * " + arr[9] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" * " + arr[9] + " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" " + arr[9] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" " + arr[9] + " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" " + arr[9] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" " + arr[9] + " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" " + arr[9] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" " + arr[9] + " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" " + arr[9] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" " + arr[9] + " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" * " + arr[9] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" * " + arr[9] + " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" * " + arr[9] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" * " + arr[9] + " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
    
    
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[7] + " " + arr[8] + " " + arr[9] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[7] + " " + arr[8] + " " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " " + arr[7] + " " + arr[8] + " " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[7] + " " + arr[8] + " " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[7] + " " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[7] + " " + arr[8] +" " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[7] + " " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[7] + " " + arr[8] +" " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[7] + " * " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[7] + " * " + arr[8] +" " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[7] + " * " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[7] + " * " + arr[8] +" " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
    
    
    
    
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[7] + " " + arr[8] + " " + arr[9] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[7] + " " + arr[8] + " " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]+ " " + arr[7] + " " + arr[8] + " " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[7] + " " + arr[8] + " " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[7] + " " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[7] + " " + arr[8] +" " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[7] + " " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[7] + " " + arr[8] +" " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[7] + " * " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[7] + " * " + arr[8] + " " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[7] + " * " + arr[8] + " " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[7] + " * " + arr[8] + " " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " " + arr[7] + " " + arr[8] + " " + arr[9] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[5] + " " + arr[7] + " " + arr[8] + " " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]+ " " + arr[7] + " " + arr[8] + " " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " " + arr[7] + " " + arr[8] + " " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5]  + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " * " + arr[7] + " " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[7] + " " + arr[8] +" " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[7] + " " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5]  + " * " + arr[7] + " " + arr[8] +" " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5]  + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " * " + arr[7] + " * " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[7] + " * " + arr[8] +" " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[7] + " * " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5]  + " * " + arr[7] + " * " + arr[8] +" " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[6] + " " + arr[7] + " " + arr[8] + " " + arr[9] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[6] + " " + arr[7] + " " + arr[8] + " " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[6]+ " " + arr[7] + " " + arr[8] + " " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[6] + " " + arr[7] + " " + arr[8] + " " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[6] + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[6]  + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[6]  + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[6]  + " * " + arr[7] + " * " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[6] + " * " + arr[7] + " " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[6]  + " * " + arr[7] + " " + arr[8] +" " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[6]  + " * " + arr[7] + " " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[6]  + " * " + arr[7] + " " + arr[8] +" " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[6] + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[6]  + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[6]  + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[6]  + " * " + arr[7] + " " + arr[8] +" * " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[6] + " * " + arr[7] + " * " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[6]  + " * " + arr[7] + " * " + arr[8] +" " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[6]  + " * " + arr[7] + " * " + arr[8] +" " + arr[9] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[6]  + " * " + arr[7] + " * " + arr[8] +" " + arr[9] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
        
        
    #345   
    if valueLastItems == 18:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        
    #3456,356,456   
    if valueLastItems == 19:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
     
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    #345678,3678,4678,5678,35678,45678,34678
    if valueLastItems == 20:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+ " " + arr[7] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " " + arr[5] + " " + arr[6]+ " " + arr[7] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+" " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6] + " " + arr[7] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " " + arr[4] + " " + arr[6]+ " " + arr[7] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+" " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[4] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[4] + " " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[4] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[4] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[4] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[4] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[4] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[4] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[4] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[4] + " " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[4] + " " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[4] + " " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[4] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[4] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[4] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[4] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[4] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[4] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[4] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[4] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[4] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[4] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[4] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[4] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[4] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[4] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[4] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[4] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[4] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[4] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]+ " " + arr[5] + " " + arr[6]+ " " + arr[7] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]+ " " + arr[5] + " " + arr[6]+ " " + arr[7] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[5] + " " + arr[6]+" " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[5] + " " + arr[6]+" * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[6] + " " + arr[7] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " " + arr[6] + " " + arr[7] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[6] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[6] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[6] + " " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[6] + " " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[6] + " " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[6] + " " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[6] + " " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[6] + " " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[6] + " " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[6] + " " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[6] + " * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[6] + " * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[6] + " * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[6] + " * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[6] + " " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[6] + " " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[6] + " " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[6] + " * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[6] + " * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[6] + " * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[6] + " * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]+ " " + arr[6] + " " + arr[7] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " * " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[6] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5]  + " * " + arr[6] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " * " + arr[6] + " " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[6] + " " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[6] + " " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5]  + " * " + arr[6] + " " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " * " + arr[6] + " " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[6] + " " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[6] + " " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5]  + " * " + arr[6] + " " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " * " + arr[6] + " * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[6] + " * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " * " + arr[6] + " * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5]  + " * " + arr[6] + " * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5]  + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " " + arr[6] + " " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " " + arr[6] + " " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5]  + " " + arr[6] + " " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " " + arr[6] + " * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " " + arr[6] + " * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5]  + " " + arr[6] + " * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5]  + " " + arr[6] + " * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[6] + " " + arr[7] + " " + arr[8] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]+ " " + arr[6] + " " + arr[7] + " " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[6] + " " + arr[7] + " " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[6] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[6] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[6] + " " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[6] + " " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[6] + " " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[6] + " " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[6] + " " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[6] + " " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[6] + " " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[6] + " " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[6] + " * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[6] + " * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[6] + " * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[6] + " * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[6] + " * " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[6] + " " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[6] + " " + arr[7] +" * " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[6] + " " + arr[7] +" * " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[6] + " * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[6] + " * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[6] + " * " + arr[7] +" " + arr[8] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[6] + " * " + arr[7] +" " + arr[8] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        
    #3456,456
    if valueLastItems == 21:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
     
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        
    #345,45,34    
    if valueLastItems == 22:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
     #345,34    
    if valueLastItems == 23:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    #345,45  
    if valueLastItems == 24:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
     #(345678910),34910,35910,36910,37910,38910
    if valueLastItems == 25:
        a = "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] +" " + arr[9] + " " + arr[10]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3]+ " " +arr[4] + " " + arr[9] + " " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " " +arr[4] + " " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]+ " " + arr[4] +" " + arr[9] + " " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]+ " * " + arr[4] +" * " + arr[9] + " * " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[4] +" * " + arr[9] + " * " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[4] +" * " + arr[9] + " * " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[4] +" * " + arr[9] + " * " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[4] +" * " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " * " +arr[4] + " * " + arr[9] + " " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[4] +" * " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[4] +" * " + arr[9] + " " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
     
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] +" " + arr[9] + " " + arr[10]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3]+ " " +arr[5] + " " + arr[9] + " " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " " +arr[5] + " " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]+ " " + arr[5] +" " + arr[9] + " " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]+ " * " + arr[5] +" * " + arr[9] + " * " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[5] +" * " + arr[9] + " * " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[5] +" * " + arr[9] + " * " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[5] +" * " + arr[9] + " * " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[5] +" * " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " * " +arr[5] + " * " + arr[9] + " " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[5] +" * " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[5] +" * " + arr[9] + " " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[6] +" " + arr[9] + " " + arr[10]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3]+ " " +arr[6] + " " + arr[9] + " " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " " +arr[6] + " " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]+ " " + arr[6] +" " + arr[9] + " " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]+ " * " + arr[6] +" * " + arr[9] + " * " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[6] +" * " + arr[9] + " * " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[6] +" * " + arr[9] + " * " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[6] +" * " + arr[9] + " * " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[6] +" * " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " * " +arr[6] + " * " + arr[9] + " " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[6] +" * " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[6] +" * " + arr[9] + " " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[7] +" " + arr[9] + " " + arr[10]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3]+ " " +arr[7] + " " + arr[9] + " " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " " +arr[7] + " " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]+ " " + arr[7] +" " + arr[9] + " " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]+ " * " + arr[7] +" * " + arr[9] + " * " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[7] +" * " + arr[9] + " * " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[7] +" * " + arr[9] + " * " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[7] +" * " + arr[9] + " * " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[7] +" * " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " * " +arr[7] + " * " + arr[9] + " " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[7] +" * " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[7] +" * " + arr[9] + " " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[8] +" " + arr[9] + " " + arr[10]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3]+ " " +arr[8] + " " + arr[9] + " " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " " +arr[8] + " " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]+ " " + arr[8] +" " + arr[9] + " " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]+ " * " + arr[8] +" * " + arr[9] + " * " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[8] +" * " + arr[9] + " * " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[8] +" * " + arr[9] + " * " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[8] +" * " + arr[9] + " * " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[8] +" * " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]+ " * " +arr[8] + " * " + arr[9] + " " + arr[10]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * "+ arr[8] +" * " + arr[9] + " " + arr[10] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * "+ arr[8] +" * " + arr[9] + " " + arr[10] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    #34567,3567,4567,3457,  
    if valueLastItems == 26:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]   + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +" " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6] + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " " + arr[6] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " " + arr[6] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " * " + arr[6] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " * " + arr[6] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " * " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " * " + arr[6] + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a +  "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6] + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " " + arr[6] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[6] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[6] + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
    #345,34,45,35
    if valueLastItems == 27:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
    #345,35    
    if valueLastItems == 28:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
      
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
    #3456,345,356
    if valueLastItems == 29:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
     
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    #3456,345,346
    if valueLastItems == 30:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
     
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
     #3456,456,346
    if valueLastItems == 31:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
     
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
    #345678,35678,3578,3678,45678,4578,4678  
    if valueLastItems == 32:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]   + " " + arr[7]  + " " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +" " + arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6]+" " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6]+" " + arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[5] + " " + arr[6]   + " " + arr[7]  + " " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " +arr[3]  + " " + arr[5] + " " + arr[6] +" " + arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " +  arr[5] + " " + arr[6]+" " + arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[5] + " " + arr[6]+" " + arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " "+ arr[5] + " * " + arr[6]+" * " + arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
             
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[7]  + " " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5]  + " "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " "+  arr[5] + " "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " "+ arr[5]  + " "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[5]  + " * "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * "+ arr[5]  + " * "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[5]  + " * "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[5]  + " "+ arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * "+ arr[5]  + " "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[5]  + " "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[5]  + " * "+ arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * "+ arr[5]  + " * "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[5]  + " * "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[5]  + " "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * "+ arr[5]  + " "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[5]  + " "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " "+ arr[5]  + " "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " "+ arr[5]  + " "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " "+ arr[5]  + " "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " "+ arr[5]  + " * "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " * " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " "+ arr[5]  + " * "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " "+ arr[5]  + " * "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " "+ arr[5]  + " * "+ arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " * " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " "+ arr[5]  + " * "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " "+ arr[5]  + " * "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[6] + " " + arr[7]  + " " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[6]  + " "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " "+  arr[6] + " "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " "+ arr[6]  + " "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[6]  + " * "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[6] + " * " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * "+ arr[6]  + " * "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[6]  + " * "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[6]  + " "+ arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[6] + " " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * "+ arr[6]  + " "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[6]  + " "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[6]  + " * "+ arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[6] + " * " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * "+ arr[6]  + " * "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[6]  + " * "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[6]  + " "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[6] + " " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " * "+ arr[6]  + " "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " * "+ arr[6]  + " "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " "+ arr[6]  + " "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[6] + " " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " "+ arr[6]  + " "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " "+ arr[6]  + " "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " "+ arr[6]  + " * "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[6] + " * " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " "+ arr[6]  + " * "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " "+ arr[6]  + " * "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " "+ arr[6]  + " * "+ arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[6] + " * " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3]  + " "+ arr[6]  + " * "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3]  + " "+ arr[6]  + " * "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[5] + " " + arr[6]   + " " + arr[7]  + " " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " +arr[4]  + " " + arr[5] + " " + arr[6] +" " + arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " +  arr[5] + " " + arr[6]+" " + arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[5] + " " + arr[6]+" " + arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " "+ arr[5] + " * " + arr[6]+" * " + arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " " + arr[5] + " * " + arr[6]+" * " + arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * " + arr[5] + " * " + arr[6]+" " + arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
             
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[7]  + " " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5]  + " "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " "+  arr[5] + " "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " "+ arr[5]  + " "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[5]  + " * "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * "+ arr[5]  + " * "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[5]  + " * "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[5]  + " "+ arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * "+ arr[5]  + " "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[5]  + " "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[5]  + " * "+ arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * "+ arr[5]  + " * "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[5]  + " * "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[5]  + " "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * "+ arr[5]  + " "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[5]  + " "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " "+ arr[5]  + " "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " "+ arr[5]  + " "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " "+ arr[5]  + " "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " "+ arr[5]  + " * "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " "+ arr[5]  + " * "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " "+ arr[5]  + " * "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " "+ arr[5]  + " * "+ arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " "+ arr[5]  + " * "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " "+ arr[5]  + " * "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[6] + " " + arr[7]  + " " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[6]  + " "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " "+  arr[6] + " "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " "+ arr[6]  + " "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[6]  + " * "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[6] + " * " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * "+ arr[6]  + " * "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[6]  + " * "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[6]  + " "+ arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[6] + " " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * "+ arr[6]  + " "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[6]  + " "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[6]  + " * "+ arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[6] + " * " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * "+ arr[6]  + " * "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[6]  + " * "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[6]  + " "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[6] + " " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " * "+ arr[6]  + " "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " * "+ arr[6]  + " "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " "+ arr[6]  + " "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[6] + " " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " "+ arr[6]  + " "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " "+ arr[6]  + " "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " "+ arr[6]  + " * "+ arr[7] +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[6] + " * " + arr[7] +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " "+ arr[6]  + " * "+ arr[7]  +" * " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " "+ arr[6]  + " * "+ arr[7]  +" * " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " "+ arr[6]  + " * "+ arr[7] +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[6] + " * " + arr[7] +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4]  + " "+ arr[6]  + " * "+ arr[7]  +" " + arr[8]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4]  + " "+ arr[6]  + " * "+ arr[7]  +" " + arr[8]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
    #3456,345,456
    if valueLastItems == 33:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
     
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[6] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]  + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
     
    #34567,3467,4567,3457,  
    if valueLastItems == 34:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]   + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +" " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" * " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " * " + arr[5] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6] + " " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6] + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " " + arr[6] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " " + arr[6] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " * " + arr[6] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " * " + arr[6] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " * " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " * " + arr[6] + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a +  "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6] + " " + arr[7]  +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6] + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " " + arr[6] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6] + " * " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[6] + " * " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6] + " * " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6] + " " + arr[7] +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " * " + arr[6] + " " + arr[7]  +"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " * " + arr[6] + " " + arr[7] +" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
       
    #34
    if valueLastItems == 6:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
    #345,35,45 
   
    
    if valueLastItems == 7:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " +arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
    #1234,234,134,124,24,34,14
    if valueLastItems == 8:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +  " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a +  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
    
        a = a +  "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
  
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
    #1234,234,124,134,14,24,34,1243,143,243
    if valueLastItems == 9:
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6] +  " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a =  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6] + " " + arr[5] + "</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[6] + " " + arr[5] +  " *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[6] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
        
        a = a +  "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[4] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[4] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
       
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
    
        a = a +  "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
        a = a +  "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[6] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[4] + " " + arr[6] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[6] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[6] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[6] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[6] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[6] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[6] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[4] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[4] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[6] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a +  "<category>"+"\n"+"   <pattern>* " +arr[3] + " " + arr[6] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n"+"\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " " + arr[6] + " " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" +"\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " " + arr[6] + " " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[6] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[6] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[3] + " * " + arr[6] + " * " + arr[5]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[3] + " * " + arr[6] + " * " + arr[5]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5] + " " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>* " + arr[5] + " * " + arr[6]+"</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
        a = a + "<category>"+"\n"+"   <pattern>" + arr[5] + " * " + arr[6]+" *</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>"+arr[2]+"</srai>"+"\n"+"   </template>"+"\n"+"</category>"+"\n" + "\n"
    
    return a

# %%
list_text = ''
file = open("/root/PycharmProjects/chat-bot/Noi thuong tru/noithuongchu.text", "r")
b=''
data={}
data['rules'] = []
count = 0
id=229
for line in open("/root/PycharmProjects/chat-bot/Noi thuong tru/noithuongchu.text").readlines(): 
    count += 1
file3 = open("/root/PycharmProjects/chat-bot/Noi thuong tru/file.text", "w")
c =''
x=1;
for i in range(count):
    list_text = file.readline()
    arr = list_text.split('$')
    print(arr.__len__())
    file2 = open("/root/PycharmProjects/chat-bot/Noi thuong tru/brain_knowledge/"+arr[1]+".aiml", "w")
    #a =  "<category>"+"\n"+"   <pattern>* THU TUC * THANH LI * VAT LIEU NO</pattern>"+ "\n"+"   <template>"+"\n"+"      <srai>TRINH TU THU TUC THANH LI PHAN LOAI VLN</srai>"+"\n"+"   </template>"+"\n"+"</category>"
    d = "<?xml version=\"1.0\" encoding=\"ISO-8859-1\"?>" + "\n" + "<aiml version=\"1.0\">" + "\n" + "meta name=\"language\" content=\"vi\"/>" + "\n" + "<!-- srai: using for reuse template of pattern and template -->" +"\n" +"<!-- noi tam tru -->" + "\n\n\n" 
    a = d + "<category>"+"\n"+"   <pattern>" + arr[2] +"</pattern>"+ "\n"+"   <template>"+arr[2]+"</template>"+"\n"+"</category>"+"\n" + "\n" + test(arr) + "</aiml>" 
    c = c + "<learn>brain_knowledge/"+arr[1]+".aiml"+"</learn>"+"\n"
    file2.write(a)
    file2.close()
    for i in range(1,len(closs)):
        floatToInt = float(arr[0])
        if closs[i][0]==floatToInt:
            data['rules'].append({'id': id ,
                                  'question': closs[i][2], 
                                  'key': arr[2],
                                  'value':closs[i][7],
                                  'link' : ''})
            id+=1
            break;

        elif(i==len(closs)-1):
            x=x+1
print(x)
with open("/root/PycharmProjects/chat-bot/Noi thuong tru/data.json", 'w',encoding='utf-8') as outfile:
    json.dump(data, outfile,sort_keys = True,ensure_ascii=False)
file3.write(c)
# Out:
# 6
# 7
# 7
# 7
# 6
# 6
# 7
# 7
# 7
# 7
# 7
# 7
# 8
# 7
# 7
# 6
# 7
# 7
# 7
# 8
# 8
# 7
# 7
# 8
# 7
# 7
# 7
# 7
# 7
# 7
# 8
# 7
# 7
# 8
# 8
# 8
# 8
# 8
# 1
# 3109
